# %% [markdown]
# # Part 1

# %%
# import relevant modules
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as sn
import scipy.stats as stats
from matplotlib.backends.backend_pdf import PdfPages
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from patsy import dmatrices
# %matplotlib inline

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("breast-cancer.csv", header=None)
data.head()
# Out:
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9   ...     22     23      24      25      26      27      28      29  \
# 0  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        30       31
# 0  0.4601  0.11890
# 1  0.2750  0.08902
# ...

# %%
with open("field_names.txt") as file:
    header = file.readlines()
    header = [line.rstrip() for line in header]

# %%
data.columns=header
data.head()
# Out:
#          ID diagnosis  radius_mean  radius_sd_error  radius_worst  \
# 0    842302         M        17.99            10.38        122.80
# 1    842517         M        20.57            17.77        132.90
# 2  84300903         M        19.69            21.25        130.00
# 3  84348301         M        11.42            20.38         77.58
# 4  84358402         M        20.29            14.34        135.10
#
#    texture_mean  texture_sd_error  texture_worst  perimeter_mean  \
# 0        1001.0           0.11840        0.27760          0.3001
# 1        1326.0           0.08474        0.07864          0.0869
# 2        1203.0           0.10960        0.15990          0.1974
# 3         386.1           0.14250        0.28390          0.2414
# 4        1297.0           0.10030        0.13280          0.1980
#
#    perimeter_sd_error  perimeter_worst  area_mean  area_sd_error  area_worst  \
# 0             0.14710           0.2419    0.07871         1.0950      0.9053
# ...

# %%
pd.set_option('display.max_column', None)

# %%
data.head()
# Out:
#          ID diagnosis  radius_mean  radius_sd_error  radius_worst  \
# 0    842302         M        17.99            10.38        122.80
# 1    842517         M        20.57            17.77        132.90
# 2  84300903         M        19.69            21.25        130.00
# 3  84348301         M        11.42            20.38         77.58
# 4  84358402         M        20.29            14.34        135.10
#
#    texture_mean  texture_sd_error  texture_worst  perimeter_mean  \
# 0        1001.0           0.11840        0.27760          0.3001
# 1        1326.0           0.08474        0.07864          0.0869
# 2        1203.0           0.10960        0.15990          0.1974
# 3         386.1           0.14250        0.28390          0.2414
# 4        1297.0           0.10030        0.13280          0.1980
#
#    perimeter_sd_error  perimeter_worst  area_mean  area_sd_error  area_worst  \
# 0             0.14710           0.2419    0.07871         1.0950      0.9053
# ...

# %%
data=data.drop(['ID'], axis=1)
data
# Out:
#     diagnosis  radius_mean  radius_sd_error  radius_worst  texture_mean  \
# 0           M        17.99            10.38        122.80        1001.0
# 1           M        20.57            17.77        132.90        1326.0
# 2           M        19.69            21.25        130.00        1203.0
# 3           M        11.42            20.38         77.58         386.1
# 4           M        20.29            14.34        135.10        1297.0
# ..        ...          ...              ...           ...           ...
# 564         M        21.56            22.39        142.00        1479.0
# 565         M        20.13            28.25        131.20        1261.0
# 566         M        16.60            28.08        108.30         858.1
# 567         M        20.60            29.33        140.10        1265.0
# 568         B         7.76            24.54         47.92         181.0
#
#      texture_sd_error  texture_worst  perimeter_mean  perimeter_sd_error  \
# ...

# %%
mean = data.groupby("diagnosis").mean()
mean
# Out:
#            radius_mean  radius_sd_error  radius_worst  texture_mean  \
# diagnosis
# B            12.146524        17.914762     78.075406    462.790196
# M            17.462830        21.604906    115.365377    978.376415
#
#            texture_sd_error  texture_worst  perimeter_mean  \
# diagnosis
# B                  0.092478       0.080085        0.046058
# M                  0.102898       0.145188        0.160775
#
#            perimeter_sd_error  perimeter_worst  area_mean  area_sd_error  \
# diagnosis
# B                    0.025717         0.174186   0.062867       0.284082
# M                    0.087990         0.192909   0.062680       0.609083
#
#            area_worst  smoothness_mean  smoothness_sd_error  smoothness_worst  \
# diagnosis
# B            1.220380         2.000321            21.135148          0.007196
# M            1.210915         4.323929            72.672406          0.006780
#
#            compactness_mean  compactness_sd_error  compactness_worst  \
# ...

# %%
median = data.groupby("diagnosis").median()
median
# Out:
#            radius_mean  radius_sd_error  radius_worst  texture_mean  \
# diagnosis
# B               12.200            17.39         78.18         458.4
# M               17.325            21.46        114.20         932.0
#
#            texture_sd_error  texture_worst  perimeter_mean  \
# diagnosis
# B                   0.09076        0.07529         0.03709
# M                   0.10220        0.13235         0.15135
#
#            perimeter_sd_error  perimeter_worst  area_mean  area_sd_error  \
# diagnosis
# B                     0.02344           0.1714   0.061540         0.2575
# M                     0.08628           0.1899   0.061575         0.5472
#
#            area_worst  smoothness_mean  smoothness_sd_error  smoothness_worst  \
# diagnosis
# B              1.1080           1.8510               19.630          0.006530
# M              1.1025           3.6795               58.455          0.006209
#
#            compactness_mean  compactness_sd_error  compactness_worst  \
# ...

# %%
mean=mean.loc[:, ["smoothness_mean" , "smoothness_sd_error", "smoothness_worst","compactness_mean" , "compactness_sd_error", "compactness_worst"]]
mean
# Out:
#            smoothness_mean  smoothness_sd_error  smoothness_worst  \
# diagnosis
# B                 2.000321            21.135148          0.007196
# M                 4.323929            72.672406          0.006780
#
#            compactness_mean  compactness_sd_error  compactness_worst
# diagnosis
# B                  0.021438              0.025997           0.009858
# M                  0.032281              0.041824           0.015060

# %%
median=median.loc[:, ["smoothness_mean" , "smoothness_sd_error", "smoothness_worst","compactness_mean" , "compactness_sd_error", "compactness_worst"]]
median
# Out:
#            smoothness_mean  smoothness_sd_error  smoothness_worst  \
# diagnosis
# B                   1.8510               19.630          0.006530
# M                   3.6795               58.455          0.006209
#
#            compactness_mean  compactness_sd_error  compactness_worst
# diagnosis
# B                   0.01631              0.018400           0.009061
# M                   0.02859              0.037125           0.014205

# %%
data.loc[data["diagnosis"]=='M', "tumor"]=1

# %%
data.loc[data["diagnosis"]=='B', "tumor"]=0

# %%
data
# Out:
#     diagnosis  radius_mean  radius_sd_error  radius_worst  texture_mean  \
# 0           M        17.99            10.38        122.80        1001.0
# 1           M        20.57            17.77        132.90        1326.0
# 2           M        19.69            21.25        130.00        1203.0
# 3           M        11.42            20.38         77.58         386.1
# 4           M        20.29            14.34        135.10        1297.0
# ..        ...          ...              ...           ...           ...
# 564         M        21.56            22.39        142.00        1479.0
# 565         M        20.13            28.25        131.20        1261.0
# 566         M        16.60            28.08        108.30         858.1
# 567         M        20.60            29.33        140.10        1265.0
# 568         B         7.76            24.54         47.92         181.0
#
#      texture_sd_error  texture_worst  perimeter_mean  perimeter_sd_error  \
# ...

# %%
data.loc[:,["diagnosis", "tumor"]]
# Out:
#     diagnosis  tumor
# 0           M    1.0
# 1           M    1.0
# 2           M    1.0
# 3           M    1.0
# 4           M    1.0
# 5           M    1.0
# 6           M    1.0
# 7           M    1.0
# 8           M    1.0
# 9           M    1.0
# 10          M    1.0
# 11          M    1.0
# 12          M    1.0
# 13          M    1.0
# 14          M    1.0
# 15          M    1.0
# 16          M    1.0
# 17          M    1.0
# 18          M    1.0
# 19          B    0.0
# 20          B    0.0
# 21          B    0.0
# 22          M    1.0
# 23          M    1.0
# 24          M    1.0
# 25          M    1.0
# 26          M    1.0
# 27          M    1.0
# 28          M    1.0
# 29          M    1.0
# 30          M    1.0
# 31          M    1.0
# 32          M    1.0
# 33          M    1.0
# 34          M    1.0
# 35          M    1.0
# 36          M    1.0
# 37          B    0.0
# 38          M    1.0
# 39          M    1.0
# 40          M    1.0
# 41          M    1.0
# ...

# %%
corr=data.loc[:, data.columns.difference(['diagnosis'])]
corr
# Out:
#      area_mean  area_sd_error  area_worst  compactness_mean  \
# 0      0.07871         1.0950      0.9053          0.049040
# 1      0.05667         0.5435      0.7339          0.013080
# 2      0.05999         0.7456      0.7869          0.040060
# 3      0.09744         0.4956      1.1560          0.074580
# 4      0.05883         0.7572      0.7813          0.024610
# 5      0.07613         0.3345      0.8902          0.033450
# 6      0.05742         0.4467      0.7732          0.013820
# 7      0.07451         0.5835      1.3770          0.030290
# 8      0.07389         0.3063      1.0020          0.035020
# 9      0.08243         0.2976      1.5990          0.072170
# 10     0.05697         0.3795      1.1870          0.009269
# 11     0.06082         0.5058      0.9849          0.040610
# 12     0.07800         0.9555      3.5680          0.082970
# 13     0.05338         0.4033      1.0780          0.031260
# 14     0.07682         0.2121      1.1690          0.059360
# ...

# %%
#above 0.5 is dangerous
cor= corr.corr(method='kendall')['tumor'].sort_values(ascending=False)
cor
# Out:
# tumor                         1.000000
# concave_points_sd_error       0.650879
# concavity_worst               0.644195
# concave_points_worst          0.643117
# fractal_dimension_mean        0.639090
# perimeter_sd_error            0.635873
# radius_worst                  0.611775
# texture_mean                  0.599992
# perimeter_mean                0.599449
# radius_mean                   0.599082
# smoothness_sd_error           0.583722
# symmetry_worst                0.576907
# smoothness_mean               0.515243
# area_sd_error                 0.504197
# texture_worst                 0.497971
# symmetry_sd_error             0.495958
# compactness_worst             0.399546
# concave_points_mean           0.389654
# compactness_sd_error          0.384486
# radius_sd_error               0.377644
# symmetry_mean                 0.347952
# fractal_dimension_sd_error    0.324380
# compactness_mean              0.311115
# texture_sd_error              0.304033
# ...

# %%
df = data([
    data(data.data, columns=data.feature_names),
    data(data.target, columns=['y'])
], axis=1)

df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-69456d7fcc45> in <module>
#       1 df = data([
# ----> 2     data(data.data, columns=data.feature_names),
#       3     data(data.target, columns=['y'])
#       4 ], axis=1)
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data'
